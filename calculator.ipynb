# %%
def simple_calculator():
    print("Welcome to the Simple Calculator! ")
    
    while True:
        print("\nSelect an operation:")
        print("1. Addition (+)")
        print("2. Subtraction (-)")
        print("3. Multiplication (*)")
        print("4. Division (/)")
        print("5. Modulus (%)")
        print("6. Power (**)")
        print("7. Integer Division (//)")
        print("Type 'exit' to quit")

        choice = input("Enter your choice (1/2/3/4/5/6/7) or 'exit' to quit: ").strip()

        if choice.lower() == 'exit':
            print("Exiting the calculator. Goodbye! ")
            break

        if choice not in ['1', '2', '3', '4', '5', '6', '7']:
            print("Hmm, that’s not a valid option. Try again, please.")
            continue

        try:
            num1 = float(input("Enter first number: "))
            num2 = float(input("Enter second number: "))
        except ValueError:
            print("Oops! Please enter valid numbers only.")
            continue

        result = None
        if choice == '1':
            result = num1 + num2
            print(f" The result of {num1} + {num2} = {result}")
        elif choice == '2':
            result = num1 - num2
            print(f" The result of {num1} - {num2} = {result}")
        elif choice == '3':
            result = num1 * num2
            print(f" The result of {num1} * {num2} = {result}")
        elif choice == '4':
            if num2 == 0:
                print("Division by zero? Nope, that’s not allowed. Try again.")
                continue
            result = num1 / num2
            print(f" The result of {num1} / {num2} = {result}")
        elif choice == '5':
            if num2 == 0:
                print("Modulus by zero? That's not gonna work. Try again.")
                continue
            result = num1 % num2
            print(f" The result of {num1} % {num2} = {result}")
        elif choice == '6':
            result = num1 ** num2
            print(f" The result of {num1} ** {num2} = {result}")
        elif choice == '7':
            if num2 == 0:
                print("Integer division by zero? Error again ")
                continue
            result = num1 // num2
            print(f" The result of {num1} // {num2} = {result}")

        again = input("\nWanna do another calculation? (yes/no): ").strip().lower()
        if again != 'yes':
            print("Cool, see you next time! ")
            break


simple_calculator()
# Out:
# Welcome to the Simple Calculator!
#
# Select an operation:
# 1. Addition (+)
# 2. Subtraction (-)
# 3. Multiplication (*)
# 4. Division (/)
# 5. Modulus (%)
# 6. Power (**)
# 7. Integer Division (//)
# Type 'exit' to quit
# Division by zero? Nope, that’s not allowed. Try again.
#
# Select an operation:
# 1. Addition (+)
# 2. Subtraction (-)
# 3. Multiplication (*)
# 4. Division (/)
# 5. Modulus (%)
# 6. Power (**)
# 7. Integer Division (//)
# Type 'exit' to quit
#  The result of 3.0 * 3.0 = 9.0
#
# Select an operation:
# 1. Addition (+)
# 2. Subtraction (-)
# 3. Multiplication (*)
# 4. Division (/)
# 5. Modulus (%)
# 6. Power (**)
# 7. Integer Division (//)
# Type 'exit' to quit
#  The result of 4.0 ** 4.0 = 256.0
# Cool, see you next time!
